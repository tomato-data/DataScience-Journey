# %%
import pandas as pd

# Specify the index of the table you want to scrape
table_index = 0

# Read in the table from the webpage
table_list = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', match='Summer Olympic Games', header=0, index_col=0)

# Select the table using the specified index
df = table_list[0]

df.head()
# Out:
#                                                    Summer Olympic Games  \
# Team
# .mw-parser-output .tooltip-dotted{border-bottom...                  No.
# Afghanistan (AFG)                                                    15
# Algeria (ALG)                                                        14
# Argentina (ARG)                                                      25
# Armenia (ARM)                                                         7
#
#                                                     Summer Olympic Games.1  \
# Team
# .mw-parser-output .tooltip-dotted{border-bottom...                     NaN
# Afghanistan (AFG)                                                      0.0
# Algeria (ALG)                                                          5.0
# Argentina (ARG)                                                       21.0
# Armenia (ARM)                                                          2.0
#
# ...

# %%
# iloc[row, column]

summer = df.iloc[1:, :5]
summer
# Out:
#                                              Summer Olympic Games  \
# Team
# Afghanistan (AFG)                                              15
# Algeria (ALG)                                                  14
# Argentina (ARG)                                                25
# Armenia (ARM)                                                   7
# Australasia (ANZ) [ANZ]                                         2
# ...                                                           ...
# Zimbabwe (ZIM) [ZIM]                                           14
# Independent Olympic Athletes (IOA) [IOA]                        3
# Independent Olympic Participants (IOP) [IOP]                    1
# Mixed team (ZZX) [ZZX]                                          3
# Totals                                                         29
#
#                                               Summer Olympic Games.1  \
# Team
# Afghanistan (AFG)                                                0.0
# ...

# %%
summer.columns = ['경기 수', '금', '은', '동', '계']
summer.head()
# Out:
#                         경기 수     금     은     동     계
# Team
# Afghanistan (AFG)         15   0.0   0.0   2.0   2.0
# Algeria (ALG)             14   5.0   4.0   8.0  17.0
# Argentina (ARG)           25  21.0  26.0  30.0  77.0
# Armenia (ARM)              7   2.0   8.0   8.0  18.0
# Australasia (ANZ) [ANZ]    2   3.0   4.0   5.0  12.0

# %%
print(summer.sort_values('금', ascending=False))
# Out:
#                                          경기 수       금       은       동        계
# Team
# Totals                                     29  5460.0  5429.0  5892.0  16781.0
# United States (USA) [P] [Q] [R] [Z] [F]    28  1061.0   830.0   738.0   2629.0
# Soviet Union (URS) [URS]                    9   395.0   319.0   296.0   1010.0
# Great Britain (GBR) [GBR] [Z]              29   284.0   318.0   314.0    916.0
# China (CHN) [CHN]                          11   263.0   199.0   174.0    636.0
# ...                                       ...     ...     ...     ...      ...
# Paraguay (PAR)                             13     0.0     1.0     0.0      1.0
# Olympic Athletes from Russia (OAR) [OAR]    0     0.0     0.0     0.0      0.0
# San Marino (SMR)                           15     0.0     1.0     2.0      3.0
# Saudi Arabia (KSA)                         12     0.0     2.0     2.0      4.0
# Lebanon (LBN)                              18     0.0     2.0     2.0      4.0
#
# ...

# %%
summer.to_excel('하계올림픽메달.xlsx')
