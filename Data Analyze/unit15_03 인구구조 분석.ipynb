# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv('age.csv', encoding='utf8', index_col=0)
df = df.div(df['2023년02월_계_총인구수'], axis=0) # 전체 데이터를 총인구수로 나눠서 비율료 변환
del df['2023년02월_계_총인구수'], df['2023년02월_계_연령구간인구수']

# %%
name = input('원하는 지역의 이름을 입력해주세요: ')
# 데이터 프레임의 인덱스 문자열에 원하는 문자열이 포함된 행을 찾아냄

a = df.index.str.contains(name) # 해당 행을 찾아서 해당 지역의 인구 구조를 저장
df2 = df[a]


plt.rc('font', family = 'AppleGothic')
plt.figure(figsize=(10, 5), dpi=300)
df.loc[np.power(df.sub(df2.iloc[0], axis=1), 5).sum(axis=1).sort_values().index[:5]].T.plot()
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요: 구리시

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rc('font', family = 'AppleGothic')
df = pd.read_csv('age.csv', encoding='utf8', index_col=0)
df = df.div(df['2023년02월_계_총인구수'], axis=0) # 전체 데이터를 총인구수로 나눠서 비율료 변환
del df['2023년02월_계_총인구수'], df['2023년02월_계_연령구간인구수']

name = input('원하는 지역의 이름을 입력해주세요: ')
# 데이터 프레임의 인덱스 문자열에 원하는 문자열이 포함된 행을 찾아냄
a = df.index.str.contains(name) # 해당 행을 찾아서 해당 지역의 인구 구조를 저장
df2 = df[a]

x = df.sub(df2.iloc[0], axis=1)
y = np.power(x, 2)
z = y.sum(axis=1)

# 여기에서 하나씩 빼서 아래 코드를 활용할 생각하기

# fig = plt.figure()
# axes = fig.add_subplot(111)
# axes.plot(x,y1,'b')

# axes = fig.add_subplot(111)
# axes.plot(x,y2,'r')
# plt.show()

i = z.sort_values().index[:5]
print(df.loc[i])


# df.loc[i].T.plot()

# plt.tick_params(
#     axis='x',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom=False,      # ticks along the bottom edge are off
#     top=False,         # ticks along the top edge are off
#     labelbottom=False) # labels along the bottom edge are off
# plt.show()
# Out:
# 원하는 지역의 이름을 입력해주세요: 구리
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...
