# %%
import numpy as np
import matplotlib.pyplot as plt

x = []
y = []
total = 0
num_5 = 0
n = 5000

for i in range(n):
    
    if np.random.randint(6) + 1 == 5:
        num_5 += 1
        
    total += 1
    x.append(i)
    y.append(num_5/total)

plt.plot(x, y)
plt.plot(x, [1/6]*n, linestyle = "dashed")

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %%
# 평균값과 기댓값
x = np.array([55, 45, 60, 40])

print(np.average(x))

p = np.array([0.8, 0.15, 0.05])
z = np.array([100, 500, 1000])

print(np.sum(p * z))
# Out:
# 50.0
# 205.0

# %%
# 분산과 표준편차

x_1 = np.array([55, 45, 60, 40])
x_2 = np.array([51, 49, 52, 48])

print(np.var(x_1))
print(np.var(x_2))
print(np.std(x_1))
print(np.std(x_2))
# Out:
# 62.5
# 2.5
# 7.905694150420948
# 1.5811388300841898

# %%
def pdf(x, mu, sigma): # mu: 평균값 sigma: 표준편차
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2 / (2*sigma**2)) # 확률밀도함수

x = np.linspace(-5, 5)
y_1 = pdf(x, 0.0, 0.5)
y_2 = pdf(x, 0.0, 1.0)
y_3 = pdf(x, 0.0, 2.0)

plt.plot(x, y_1, label="σ: 0.5", linestyle="dashed")
plt.plot(x, y_2, label="σ: 1.0", linestyle="solid")
plt.plot(x, y_3, label="σ: 2.0", linestyle="dashdot")
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %%
# 정규분포를 따르는 난수 생성
s = np.random.normal(0, 1, 10000) # 평균 0, 표준편차 1, 10000개

# 히스토그램
plt.hist(s, bins=25)

plt.xlabel("x", size=14)
plt.grid()

plt.show()

# %%
# 거듭제곱 법칙

def power_func(x, c, k):
    return c*x**(-k)

x = np.linspace(1, 5)
y_1 = power_func(x, 1.0, 1.0) # c:1.0 k:1.0
y_2 = power_func(x, 1.0, 2.0) # c:1.0 k:2.0
y_3 = power_func(x, 1.0, 4.0) # c:1.0 k:4.0

plt.plot(x, y_1, label="k:1.0", linestyle="dashed")
plt.plot(x, y_2, label="k:2.0", linestyle="solid")
plt.plot(x, y_3, label="k:4.0", linestyle="dashdot")
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %%
# pareto distribution
s = np.random.pareto(4, 1000)

plt.hist(s, bins=25)

plt.xlabel("x", size=14)
plt.grid()

plt.show()

# %%
x = np.array([50, 70, 40, 60, 80])
y = np.array([60, 80, 50, 50, 70])
z = np.array([60, 40, 60, 40, 30])

cov_xy = np.average((x-np.average(x))*(y-np.average(y)))
print("cov_xy", cov_xy)

cov_xz = np.average((x-np.average(x))*(z-np.average(z)))
print("cov_xz", cov_xz)

plt.scatter(x, y, marker="o", label="xy", s=40) # s 는 마커의 크기
plt.scatter(x, z, marker="x", label="xz", s=60)
plt.legend()

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()
# Out:
# cov_xy 120.0
# cov_xz -160.0

# %%
# 공분산
import numpy as np
import matplotlib.pyplot as plt

def show_cov(cov):
    print("--- Covariance:", cov, " ---")
    average = np.array([0, 0]) # x,y 각각의 평균
    cov_matrix = np.array([[1, cov], # 공분산을 행렬로 지정
                          [cov, 1]])
    
    # 공분산으로부터 페어 데이터를 3000짝 생성
    #data는 (3000, 2)의 형상의 행렬이 됨
    data = np.random.multivariate_normal(average, cov_matrix, 3000)
    x = data[:, 0] # 처음 열을 x 좌표로
    y = data[:, 1] # 다음 열을 y 좌표로
    
    plt.scatter(x, y, marker = "x", s = 20)
    
    plt.title("--- Covariance:" + str(cov) + " ---")
    plt.xlabel("x", size=14)
    plt.ylabel("y", size=14)
    plt.grid()
    
    plt.show()
    
show_cov(0.6)
show_cov(0.0)
show_cov(-0.6)
# Out:
# --- Covariance: 0.6  ---
# --- Covariance: 0.0  ---
# --- Covariance: -0.6  ---

# %%
x = np.array([50, 70, 40, 60, 80])
y = np.array([60, 80, 50, 50, 70])

print("--- corrcoef() 함수 사용 ---")
print(np.corrcoef(x, y)) # 상관계수

print()

print("--- 공분산과 표준편차로부터 구한다 ---")
cov_xy = np.average((x-np.average(x))*(y-np.average(y))) # 공분산
print(cov_xy/(np.std(x)*np.std(y)))

plt.scatter(x,y)

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()
# Out:
# --- corrcoef() 함수 사용 ---
# [[1.         0.72760688]
#  [0.72760688 1.        ]]
#
# --- 공분산과 표준편차로부터 구한다 ---
# 0.7276068751089989

# %%
#우도가 작은 케이스

x_data = np.array([2.4, 1.2, 3.5, 2.1, 4.7]) #데이터
y_data = np.zeros(5) # x_data를 산포도로 표시하기위한 편의적인 데이터

mu = 0
sigma = 1

def pdf(x, mu, sigma): # mu: 평균값 sigma: 표준편차
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2 / (2*sigma**2))

x_pdf = np.linspace(-5, 5)
y_pdf = pdf(x_pdf, mu, sigma)

plt.scatter(x_data, y_data)
plt.plot(x_pdf, y_pdf)

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

print("--- 우도 ---")
print(np.prod(pdf(x_data, mu, sigma))) # 식 (1)에 의한 우도를 계산

print("--- 대수우도 ---")
print(np.sum(np.log(pdf(x_data, mu, sigma))))
# 식(2)에 의한 대수우도를 계산
# Out:
# --- 우도 ---
# 1.0632480805734735e-12
# --- 대수우도 ---
# -27.569692666023364

# %%
#우도가 큰 케이스

x_data = np.array([2.4, 1.2, 3.5, 2.1, 4.7]) #데이터
y_data = np.zeros(5) # x_data를 산포도로 표시하기위한 편의적인 데이터

mu = np.average(x_data)
sigma = np.std(x_data)

def pdf(x, mu, sigma): # mu: 평균값 sigma: 표준편차
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2 / (2*sigma**2))

x_pdf = np.linspace(-3, 7)
y_pdf = pdf(x_pdf, mu, sigma)

plt.scatter(x_data, y_data)
plt.plot(x_pdf, y_pdf)

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

print("--- 우도 ---")
print(np.prod(pdf(x_data, mu, sigma))) # 식 (1)에 의한 우도를 계산

print("--- 대수우도 ---")
print(np.sum(np.log(pdf(x_data, mu, sigma))))
# 식(2)에 의한 대수우도를 계산
# Out:
# --- 우도 ---
# 0.0003211757807192693
# --- 대수우도 ---
# -8.043521981227514

# %%
# 평균값 고정 후 표준편차를 변경 했을 때의 우도변화

#우도

x_data = np.array([2.4, 1.2, 3.5, 2.1, 4.7]) #데이터

mu = np.average(x_data)
sigma = np.std(x_data)

def pdf(x, mu, sigma): # mu: 평균값 sigma: 표준편차
    return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(x-mu)**2 / (2*sigma**2))

def log_likelyhood(p):
    return np.sum(np.log(p)) # 대수우도

x_sigma = np.linspace(0.5, 8)
y_loglike = []
for s in x_sigma:
    log_like = log_likelyhood(pdf(x_data, mu, s))
    y_loglike.append(log_like)
    
plt.plot(x_sigma, np.array(y_loglike))
plt.plot([sigma, sigma], [min(y_loglike), max(y_loglike)], linestyle = "dashed")

plt.xlabel("x_sigma", size=14)
plt.ylabel("y_loglike", size=14)
plt.grid()

plt.show()

# %%
x = np.linspace(0.01, 1) # 0의 대수는 취할 수 없음
y = -np.log2(x) # 선택정보량

plt.plot(x, y)

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %%
# 확률과 평균정보량의 그래프

x = np.linspace(0.01, 0.99)
y = -x*np.log2(x) - (1-x)*np.log2(1-x) # 평균정보량

plt.plot(x, y)

plt.xlabel("x", size=14)
plt.ylabel("y", size=14)
plt.grid()

plt.show()

# %%
delta = 1e-7

def cross_entropy(p, t):
    return -np.sum(t*np.log(p+delta) + (1-t)*np.log(1-p+delta)) # 교차 엔트로피

# 예측
p_1 = np.array([0.2, 0.8, 0.1, 0.3, 0.9, 0.7]) # 정답으로부터 떨어져있다
p_2 = np.array([0.7, 0.3, 0.9, 0.9, 0.1, 0.2]) # 정답에 가깝다
t = np.array([1, 0, 1, 1, 0, 0]) # 정답

print(cross_entropy(p_1, t))
print(cross_entropy(p_2, t))
# Out:
# 10.231987952842859
# 1.2525742421175814

# %%
p = 0.6

print(-p*np.log2(p)-(1-p)*np.log2(1-p))
# Out:
# 0.9709505944546686
