# %%
# checks encoding
import chardet

with open('ns_book.csv', mode='rb') as f:
    d = f.readline()
print(chardet.detect(d))
# Out:
# {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}

# %%
# csv 파일은 pandas 같은 도구로 읽는 것이 편리하지만 아주 큰 파일을 열 때는 오랜 시간이 걸리거나 아예 열 수 없을 때도 있음.
# 그럴 때는 아래왁 같이 처음 몇 줄을 출력해 보는 것이 빠르게 파일의 내용 확인할 수 있는 좋은 방법

with open('ns_book.csv', encoding='EUC-KR') as f:
    print(f.readline())
    print(f.readline())
# Out:
# 번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,
#
# "1","(브루스 커밍스의)한국현대사","브루스 커밍스 지음","창작과비평사","2001","9788936482190","","0","","911.07","2","50","2023-12-18",

# %%
import pandas as pd

df = pd.read_csv('ns_book.csv', encoding='EUC-KR', low_memory=False)

# %%
df.head()
# Out:
#    번호                                     도서명                 저자     출판사  \
# 0   1                         (브루스 커밍스의)한국현대사         브루스 커밍스 지음  창작과비평사
# 1   2                                 시지프 신화   알베르 카뮈 지음 ;김화영 옮김     민음사
# 2   3  TAKEOUT 유럽역사문명:지식 바리스타 하광용의 인문학 에스프레소              하광용 지음     파람북
# 3   4                            역사의 연구:신축약판   아놀드 토인비 지음;김진원 엮음    바른북스
# 4   5                            역사의 연구:신축약판   아놀드 토인비 지음;김진원 엮음    바른북스
#
#    발행년도           ISBN  세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수        등록일자  \
# 0  2001  9788936482190      NaN    0  NaN  911.07     2    50  2023-12-18
# 1  2016  9788937463433      NaN    0  343     808     1     1  2023-12-17
# 2  2023  9791192964683      NaN    0    2   001.3     1     1  2023-12-17
# 3  2017  9791188363520      NaN    0    1     907     1     0  2023-12-17
# 4  2023  9791192942513      NaN    0    2     907     1     0  2023-12-17
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# ...

# %%
df.to_csv('ns_202312.csv')

# %%
with open('ns_202312.csv') as f:
    for i in range(3):
        print(f.readline(), end='')
# Out:
# ,번호,도서명,저자,출판사,발행년도,ISBN,세트 ISBN,부가기호,권,주제분류번호,도서권수,대출건수,등록일자,Unnamed: 13
# 0,1,(브루스 커밍스의)한국현대사,브루스 커밍스 지음,창작과비평사,2001,9788936482190,,0,,911.07,2,50,2023-12-18,
# 1,2,시지프 신화 ,알베르 카뮈 지음 ;김화영 옮김,민음사,2016,9788937463433,,0,343,808,1,1,2023-12-17,

# %%
# csv 파일로 변환하는 과정에서 인덱스 column이 추가됨

ns_df = pd.read_csv('ns_202312.csv', low_memory=False)
ns_df.head()
# Out:
#    Unnamed: 0  번호                                     도서명                 저자  \
# 0           0   1                         (브루스 커밍스의)한국현대사         브루스 커밍스 지음
# 1           1   2                                 시지프 신화   알베르 카뮈 지음 ;김화영 옮김
# 2           2   3  TAKEOUT 유럽역사문명:지식 바리스타 하광용의 인문학 에스프레소              하광용 지음
# 3           3   4                            역사의 연구:신축약판   아놀드 토인비 지음;김진원 엮음
# 4           4   5                            역사의 연구:신축약판   아놀드 토인비 지음;김진원 엮음
#
#       출판사  발행년도           ISBN  세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수  \
# 0  창작과비평사  2001  9788936482190      NaN    0  NaN  911.07     2    50
# 1     민음사  2016  9788937463433      NaN    0  343     808     1     1
# 2     파람북  2023  9791192964683      NaN    0    2   001.3     1     1
# 3    바른북스  2017  9791188363520      NaN    0    1     907     1     0
# 4    바른북스  2023  9791192942513      NaN    0    2     907     1     0
#
#          등록일자  Unnamed: 13
# 0  2023-12-18          NaN
# ...

# %%
# index_col 매개변수로 해결하거나 애초에 저장할 때 index 매개변수를 False로 설정
# df.to_csv('ns_202312.csv', index=False)

ns_df = pd.read_csv('ns_202312.csv', index_col=0, low_memory=False)
ns_df.head()
# Out:
#    번호                                     도서명                 저자     출판사  \
# 0   1                         (브루스 커밍스의)한국현대사         브루스 커밍스 지음  창작과비평사
# 1   2                                 시지프 신화   알베르 카뮈 지음 ;김화영 옮김     민음사
# 2   3  TAKEOUT 유럽역사문명:지식 바리스타 하광용의 인문학 에스프레소              하광용 지음     파람북
# 3   4                            역사의 연구:신축약판   아놀드 토인비 지음;김진원 엮음    바른북스
# 4   5                            역사의 연구:신축약판   아놀드 토인비 지음;김진원 엮음    바른북스
#
#    발행년도           ISBN  세트 ISBN 부가기호    권  주제분류번호  도서권수  대출건수        등록일자  \
# 0  2001  9788936482190      NaN    0  NaN  911.07     2    50  2023-12-18
# 1  2016  9788937463433      NaN    0  343     808     1     1  2023-12-17
# 2  2023  9791192964683      NaN    0    2   001.3     1     1  2023-12-17
# 3  2017  9791188363520      NaN    0    1     907     1     0  2023-12-17
# 4  2023  9791192942513      NaN    0    2     907     1     0  2023-12-17
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# ...
