# %%
# 웹 기반 API로 데이터를 전달할 때는 파이썬 딕셔너리가 아닌 텍스트로 전달해야함

d = {'name': '혼자 공부하는 데이터 분석'}
print(d['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
import json

d_str = json.dumps(d, ensure_ascii=False)
print(d_str)
# Out:
# {"name": "혼자 공부하는 데이터 분석"}

# %%
d2 = json.loads(d_str)
print(d2['name'])
print(type(d2))
# Out:
# 혼자 공부하는 데이터 분석
# <class 'dict'>

# %%
d3 = json.loads('{"name": "혼자 공부하는 데이터 분석", "author": ["박해선", "홍길동"], \
"year": 2022}')

print(d3['author'][1])
# Out:
# 홍길동

# %%
d4_str = """
[
{"name": "혼자 공부하는 데이터 분석", "author": "박해선", "year": 2022},
{"name": "혼자 공부하는 머신러닝+딥러닝", "author": "박해선", "year": 2020}
]
"""
d4 = json.loads(d4_str)
print(d4[0]['name'])
# Out:
# 혼자 공부하는 데이터 분석

# %%
import pandas as pd

pd.read_json(d4_str)
# Out:
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %%
# 파이썬 객체를 활용하는 방법

pd.DataFrame(d4)
# Out:
#                name author  year
# 0    혼자 공부하는 데이터 분석    박해선  2022
# 1  혼자 공부하는 머신러닝+딥러닝    박해선  2020

# %%
import xml.etree.ElementTree as et

x_str = """
<book>
	<name>혼자 공부하는 데이터 분석</name>
	<author>박해선</author>
	<year>2022</year>
</book>
"""
book = et.fromstring(x_str)
print(type(book))
print(book.tag)
# Out:
# <class 'xml.etree.ElementTree.Element'>
# book

# %%
book_childs = list(book)
print(book_childs)

name, author, year = book_childs
print(name.text, author.text, year.text)
# Out:
# [<Element 'name' at 0x7fd45918bf90>, <Element 'author' at 0x7fd45918bf40>, <Element 'year' at 0x7fd459188040>]
# 혼자 공부하는 데이터 분석 박해선 2022

# %%
name = book.findtext('name')
author = book.findtext('author')
year = book.findtext('year')
print(name, author, year)
# Out:
# 혼자 공부하는 데이터 분석 박해선 2022

# %%
x2_str = """
<books>
	<book>
		<name>혼자 공부하는 데이터 분석</name>
		<author>박해선</author>
		<year>2022</year>
	</book>
	<book>
		<name>혼자 공부하는 데이터 머신러닝+딥러닝</name>
		<author>박해선</author>
		<year>2020</year>
	</book>
</books>
"""

books = et.fromstring(x2_str)
print(books.tag)
# Out:
# books

# %%
for book in books.findall('book'):
    name = book.findtext('name')
    author = book.findtext('author')
    year = book.findtext('year')
    print(name)
    print(author)
    print(year)
    print()
# Out:
# 혼자 공부하는 데이터 분석
# 박해선
# 2022
#
# 혼자 공부하는 데이터 머신러닝+딥러닝
# 박해선
# 2020

# %%
import requests

url = 'http://data4library.kr/api/loanItemSrch?format=json&startDt=2023-11-01\
&endDt=2023-11-30&age=20&region=11;31&addCode=0&kdc=6&pageNo=1&pageSize=10\
&authKey=d87c24a4b428d9561a903f266e3c73080faf45d883077c3f9af9e960c6e85269'

r = requests.get(url)

# %%
data = r.json()
print(data)
# Out:
# {'response': {'request': {'startDt': '2023-11-01', 'endDt': '2023-11-30', 'age': '20', 'addCode': '0', 'kdc': '6', 'region': '11;31', 'pageNo': 1, 'pageSize': 10}, 'resultNum': 10, 'numFound': 5000, 'docs': [{'doc': {'no': 1, 'ranking': '1', 'bookname': '당신은 사건 현장에 있습니다 :일러스트 한 장으로 즐기는 추리 게임 ', 'authors': '글: 모데스토 가르시아 ;번역: 엄지영', 'publisher': '중앙일보에스', 'publication_year': '2022', 'isbn13': '9788927812975', 'addition_symbol': '03030', 'vol': '', 'class_no': '691.9', 'class_nm': '예술 > 오락, 운동 > 오락', 'loan_count': '39', 'bookImageURL': 'https://image.aladin.co.kr/product/29623/60/cover/8927812972_2.jpg', 'bookDtlUrl': 'https://data4library.kr/bookV?seq=6479562'}}, {'doc': {'no': 2, 'ranking': '2', 'bookname': '나는 앞으로 몇 번의 보름달을 볼 수 있을까 ', 'authors': '지은이: 류이치 사카모토 ;옮긴이: 황국영', 'publisher': '위즈덤하우스', 'publication_year': '2023', 'isbn13': '9791168126541', 'addition_symbol': '03830', 'vol': '', 'class_no': '670.4', 'class_nm': '예술 > 음악 > 음악', 'loan_count': '37', 'bookImageURL': 'https://image
# ...

# %%
data
# Out:
# {'response': {'request': {'startDt': '2023-11-01',
#    'endDt': '2023-11-30',
#    'age': '20',
#    'addCode': '0',
#    'kdc': '6',
#    'region': '11;31',
#    'pageNo': 1,
#    'pageSize': 10},
#   'resultNum': 10,
#   'numFound': 5000,
#   'docs': [{'doc': {'no': 1,
#      'ranking': '1',
#      'bookname': '당신은 사건 현장에 있습니다 :일러스트 한 장으로 즐기는 추리 게임 ',
#      'authors': '글: 모데스토 가르시아 ;번역: 엄지영',
#      'publisher': '중앙일보에스',
#      'publication_year': '2022',
#      'isbn13': '9788927812975',
#      'addition_symbol': '03030',
#      'vol': '',
#      'class_no': '691.9',
#      'class_nm': '예술 > 오락, 운동 > 오락',
#      'loan_count': '39',
#      'bookImageURL': 'https://image.aladin.co.kr/product/29623/60/cover/8927812972_2.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6479562'}},
#    {'doc': {'no': 2,
#      'ranking': '2',
#      'bookname': '나는 앞으로 몇 번의 보름달을 볼 수 있을까 ',
#      'authors': '지은이: 류이치 사카모토 ;옮긴이: 황국영',
#      'publisher': '위즈덤하우스',
# ...

# %%
books = []
for d in data['response']['docs']:
    books.append(d['doc'])
books
# Out:
# [{'no': 1,
#   'ranking': '1',
#   'bookname': '당신은 사건 현장에 있습니다 :일러스트 한 장으로 즐기는 추리 게임 ',
#   'authors': '글: 모데스토 가르시아 ;번역: 엄지영',
#   'publisher': '중앙일보에스',
#   'publication_year': '2022',
#   'isbn13': '9788927812975',
#   'addition_symbol': '03030',
#   'vol': '',
#   'class_no': '691.9',
#   'class_nm': '예술 > 오락, 운동 > 오락',
#   'loan_count': '39',
#   'bookImageURL': 'https://image.aladin.co.kr/product/29623/60/cover/8927812972_2.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6479562'},
#  {'no': 2,
#   'ranking': '2',
#   'bookname': '나는 앞으로 몇 번의 보름달을 볼 수 있을까 ',
#   'authors': '지은이: 류이치 사카모토 ;옮긴이: 황국영',
#   'publisher': '위즈덤하우스',
#   'publication_year': '2023',
#   'isbn13': '9791168126541',
#   'addition_symbol': '03830',
#   'vol': '',
#   'class_no': '670.4',
#   'class_nm': '예술 > 음악 > 음악',
#   'loan_count': '37',
#   'bookImageURL': 'https://image.aladin.co.kr/product/31959/75/cover/k802833350_3.jpg',
#   'bookDtlUrl': 'https://data4library.kr/bookV?seq=6718951'},
# ...

# %%
books_df = pd.DataFrame(books)
books_df
# Out:
#    no ranking                                           bookname  \
# 0   1       1             당신은 사건 현장에 있습니다 :일러스트 한 장으로 즐기는 추리 게임
# 1   2       2                          나는 앞으로 몇 번의 보름달을 볼 수 있을까
# 2   3       3                  사실은 이것도 디자인입니다 :일상 속 숨겨진 디자인의 비밀
# 3   4       4                   방구석 미술관 :가볍고 편하게 시작하는 유쾌한 교양 미술
# 4   5       5  모든 것은 기본에서 시작한다 :실력도 기술도 사람 됨됨이도, 기본을 지키는 손웅정의...
# 5   6       6                    김이나의 작사법 :우리의 감정을 사로잡는 일상의 언어들
# 6   7       6                                        정확한 사랑의 실험
# 7   8       8                                            방구석 미술관
# 8   9       8                               모국어는 차라리 침묵 :목정원 산문
# 9  10      10                   있는 공간, 없는 공간 :대한민국 1등 핫플레이스의 법칙
#
#                    authors publisher publication_year         isbn13  \
# 0    글: 모데스토 가르시아 ;번역: 엄지영    중앙일보에스             2022  9788927812975
# 1  지은이: 류이치 사카모토 ;옮긴이: 황국영    위즈덤하우스             2023  9791168126541
# ...

# %%
books_df.to_json('20s_best_book.json')

# %%
# books = books_df[['no', 'ranking', 'bookname', 'authors', 'publisher', 'publication_year', 'isbn13']]
# books.head()

books_df.loc[[0, 1], ['bookname', 'authors']]
# Out:
#                                  bookname                  authors
# 0  당신은 사건 현장에 있습니다 :일러스트 한 장으로 즐기는 추리 게임     글: 모데스토 가르시아 ;번역: 엄지영
# 1               나는 앞으로 몇 번의 보름달을 볼 수 있을까   지은이: 류이치 사카모토 ;옮긴이: 황국영

# %%
books = books_df.loc[:, 'no':'isbn13']
books.head()
# Out:
#    no ranking                                           bookname  \
# 0   1       1             당신은 사건 현장에 있습니다 :일러스트 한 장으로 즐기는 추리 게임
# 1   2       2                          나는 앞으로 몇 번의 보름달을 볼 수 있을까
# 2   3       3                  사실은 이것도 디자인입니다 :일상 속 숨겨진 디자인의 비밀
# 3   4       4                   방구석 미술관 :가볍고 편하게 시작하는 유쾌한 교양 미술
# 4   5       5  모든 것은 기본에서 시작한다 :실력도 기술도 사람 됨됨이도, 기본을 지키는 손웅정의...
#
#                    authors publisher publication_year         isbn13
# 0    글: 모데스토 가르시아 ;번역: 엄지영    중앙일보에스             2022  9788927812975
# 1  지은이: 류이치 사카모토 ;옮긴이: 황국영    위즈덤하우스             2023  9791168126541
# 2                   김성연 지음     한빛미디어             2023  9791169211307
# 3                   조원재 지음       백도씨             2018  9788968331862
# 4                   손웅정 지음      수오서재             2021  9791190382502

# %%
isbn = 9788927812975
url = 'https://www.yes24.com/Product/Search?domain=ALL&query={}'.format(isbn)
r = requests.get(url)
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title> 9788927812975 - 예스24</title>
#
# 	<meta name="title" content="예스24" />
# 	<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" />
#
#
# 	<link title="YES24" rel="search" type="application/opensearchdescription+xml" href="//www.yes24.com/OpensearchDescription.xml">
#
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(r.text, 'html.parser')
prd_link = soup.find('a', attrs={'class':'gd_name'})

# %%
print(prd_link)
print(prd_link['href'])
# Out:
# <a class="gd_name" href="/Product/Goods/110031571" onclick="wiseLogV2('S', '101_005_003_001', ''); setGoodsClickExtraCodeHub('032', '9788927812975', '110031571', '0');">당신은 사건 현장에 있습니다 </a>
# /Product/Goods/110031571

# %%
url = 'http://www.yes24.com'+prd_link['href']
r = requests.get(url)
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head><link rel="canonical" href="https://m.yes24.com/Goods/Detail/110031571">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title>당신은 사건 현장에 있습니다  - 예스24 </title>
#
#
# <meta name="title" content="당신은 사건 현장에 있습니다 "/>
# <meta name="author" content="모데스토 가르시아 저/하비 데 카스트로 그림 " />
#
# <meta name="description" content="모데스토 가르시아 저/하비 데 카스트로 그림 . 중앙북스(books). 판매가 25,200원(10% 할인). 포인트 1,400원(5% 적립). 유럽 전역에서 선풍적인 인기를 끌었던 신개념 추리게임북, 드디어 한국 상륙!사건 현장에 숨겨진 진실을 파헤쳐라!공항,..."/>
#
# ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
prd_detail = soup.find('div', attrs={'id':'infoset_specific'})
print(prd_detail)
# Out:
# <div class="gd_infoSet infoSet_noLine" id="infoset_specific">
# <div class="tm_infoSet">
# <h4 class="tit_txt">품목정보</h4>
# </div>
# <div class="infoSetCont_wrap">
# <div class="yesTb">
# <table class="tb_nor tb_vertical" summary="품목정보 국내도서, 외국도서 " width="100%">
# <caption>품목정보</caption>
# <colgroup>
# <col width="170"/>
# <col width="*"/>
# </colgroup>
# <tbody class="b_size">
# <tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2022년 05월 30일</td>
# </tr>
# <tr>
# <th class="txt" scope="row">판형</th>
# <td class="txt lastCol">
#                                     양장
#                                     <a class="bgYUI ico_comm ico_help" href="javascript:void(0);" onclick="$.yesPop('dPop_binding',this,{cock:true,mask:false,pWidth:640,ajaxURL : '/Product/Goods/Popup?id=dPop_bookBindingMethodInfo'});" title="도서 제본방식 안내">도서 제본방식 안내</a>
# </td>
# </tr>
# <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">224쪽 | 742g | 212*212*17mm</td>
# ...

# %%
prd_tr_list = prd_detail.find_all('tr')
print(prd_tr_list)
# Out:
# [<tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2022년 05월 30일</td>
# </tr>, <tr>
# <th class="txt" scope="row">판형</th>
# <td class="txt lastCol">
#                                     양장
#                                     <a class="bgYUI ico_comm ico_help" href="javascript:void(0);" onclick="$.yesPop('dPop_binding',this,{cock:true,mask:false,pWidth:640,ajaxURL : '/Product/Goods/Popup?id=dPop_bookBindingMethodInfo'});" title="도서 제본방식 안내">도서 제본방식 안내</a>
# </td>
# </tr>, <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">224쪽 | 742g | 212*212*17mm</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN13</th>
# <td class="txt lastCol">9788927812975</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN10</th>
# <td class="txt lastCol">8927812972</td>
# </tr>]

# %%
for tr in prd_tr_list:
    if tr.find('th').get_text() == '쪽수, 무게, 크기':
        page_td = tr.find('td').get_text()
        break
print(page_td.split()[0])
# Out:
# 224쪽

# %%
def get_page_cnt(isbn):
    url = 'http://www.yes24.com/Product/Search?domain=Book&query={}'
    r = requests.get(url.format(isbn))
    soup = BeautifulSoup(r.text, 'html.parser')
    prd_info = soup.find('a', attrs={'class':'gd_name'})
    url = 'https://www.yes24.com'+prd_info['href']
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    prd_detail = soup.find('div', attrs={'id':'infoset_specific'})
    prd_tr_list = prd_detail.find_all('tr')
    for tr in prd_tr_list:
        if tr.find('th').get_text() == '쪽수, 무게, 크기':
            return tr.find('td').get_text().split()[0]
    return ''

# %%
top10_books = books.head(10)

def get_page_cnt2(row):
    isbn = row['isbn13']
    return get_page_cnt(isbn)

page_count = top10_books.apply(get_page_cnt2, axis=1)
print(page_count)
# Out:
# 0    224쪽
# 1    396쪽
# 2    240쪽
# 3    344쪽
# 4    284쪽
# 5    368쪽
# 6    240쪽
# 7    424쪽
# 8    188쪽
# 9    228쪽
# dtype: object

# %%
page_count.name = 'page_count'
print(page_count)
# Out:
# 0    224쪽
# 1    396쪽
# 2    240쪽
# 3    344쪽
# 4    284쪽
# 5    368쪽
# 6    240쪽
# 7    424쪽
# 8    188쪽
# 9    228쪽
# Name: page_count, dtype: object

# %%
top10_with_page_count = pd.merge(top10_books, page_count, left_index=True, right_index=True)
top10_with_page_count
# Out:
#    no ranking                                           bookname  \
# 0   1       1             당신은 사건 현장에 있습니다 :일러스트 한 장으로 즐기는 추리 게임
# 1   2       2                          나는 앞으로 몇 번의 보름달을 볼 수 있을까
# 2   3       3                  사실은 이것도 디자인입니다 :일상 속 숨겨진 디자인의 비밀
# 3   4       4                   방구석 미술관 :가볍고 편하게 시작하는 유쾌한 교양 미술
# 4   5       5  모든 것은 기본에서 시작한다 :실력도 기술도 사람 됨됨이도, 기본을 지키는 손웅정의...
# 5   6       6                    김이나의 작사법 :우리의 감정을 사로잡는 일상의 언어들
# 6   7       6                                        정확한 사랑의 실험
# 7   8       8                                            방구석 미술관
# 8   9       8                               모국어는 차라리 침묵 :목정원 산문
# 9  10      10                   있는 공간, 없는 공간 :대한민국 1등 핫플레이스의 법칙
#
#                    authors publisher publication_year         isbn13  \
# 0    글: 모데스토 가르시아 ;번역: 엄지영    중앙일보에스             2022  9788927812975
# 1  지은이: 류이치 사카모토 ;옮긴이: 황국영    위즈덤하우스             2023  9791168126541
# ...
